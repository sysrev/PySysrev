# %%
import requests
import pandas as pd

def getAnnotations(project_id):
    url = 'https://sysrev.com/web-api/project-annotations?project-id=' + str(project_id)
    response = requests.get(url)
    result = response.json()["result"]
    
    data = {}
    data['selection'] = [x['selection'] for x in result]
    data['annotation'] = [x['annotation'] for x in result]
    data['semantic_class'] = [x['semantic-class'] for x in result]
    data['external_id'] = [x['pmid'] for x in result]
    data['sysrev_id'] = [x['article-id'] for x in result]
    data['text'] = [x['context']['text-context'] for x in result]
    data['start'] = [x['context']['start-offset'] if 'start-offset' in x['context'].keys() else None for x in result]
    data['end'] = [x['context']['end-offset'] if 'end-offset' in x['context'].keys() else None for x in result]
    data['datasource'] = ['pubmed'] * len(result)

    df = pd.DataFrame.from_dict(data)
    return df

# %%
df = getAnnotations(3144)
df
# Out:
#          annotation datasource     end  external_id  \
# 0            α-KGDH     pubmed   286.0     29211711
# 1             KAT2A     pubmed   391.0     29211711
# 2              GCN5     pubmed   411.0     29211711
# 3      succinyl-CoA     pubmed   493.0     29211711
# 4             KAT2A     pubmed   509.0     29211711
# 5             KAT2A     pubmed   565.0     29211711
# 6      succinyl-CoA     pubmed   594.0     29211711
# 7      succinyl-CoA     pubmed   638.0     29211711
# 8             KAT2A     pubmed   669.0     29211711
# 9      succinyl-CoA     pubmed   969.0     29211711
# 10       acetyl-CoA     pubmed   985.0     29211711
# 11            KAT2A     pubmed   992.0     29211711
# 12           α-KGDH     pubmed  1158.0     29211711
# 13     succinyl-CoA     pubmed  1433.0     29211711
# 14          α-KGDH      pubmed  1456.0     29211711
# 15            KAT2A     pubmed  1518.0     29211711
# 16             DEC2     pubmed   825.0     29466367
# 17             DEC2     pubmed  1163.0     29466367
# 18            TNF-α     pubmed   593.0     29274398
# 19              TNF     pubmed   157.0     29274398
# 20              TNF     pubmed   786.0     29274398
# 21           TNF-α      pubmed   847.0     29274398
# 22            TNF-α     pubmed  1210.0     29274398
# 23            EF-1α     pubmed   672.0     28557288
# 24           EEF1A1     pubmed   692.0     28557288
# 25            EF-1α     pubmed  1251.0     28557288
# 26              WT1     pubmed   250.0     28825729
# 27           CTNNB1     pubmed   258.0     28825729
# 28            AMER1     pubmed   265.0     28825729
# 29           DROSHA     pubmed   273.0     28825729
# ...             ...        ...     ...          ...
# 8197            JAK     pubmed    28.0     29228427
# 8198          SOCS3     pubmed   251.0     29228427
# 8199         p-JAK1     pubmed  1585.0     29228427
# 8200         p-JAK2     pubmed  1593.0     29228427
# 8201        p-STAT3     pubmed  1602.0     29228427
# 8202         c-FLIP     pubmed    41.0     29045468
# 8203          NF-κB     pubmed   139.0     29045468
# 8204        c-FLIPL     pubmed   622.0     29045468
# 8205        GADD45B     pubmed   783.0     29045468
# 8206           MKK7     pubmed   817.0     29045468
# 8207    phospho-JNK     pubmed   833.0     29045468
# 8208            Bax     pubmed  1225.0     29045468
# 8209            p53     pubmed   375.0     28827596
# 8210         CDKN1a     pubmed   774.0     28827596
# 8211            EHF     pubmed   378.0     28549169
# 8212           APIP     pubmed   416.0     28549169
# 8213           ELF5     pubmed   829.0     28549169
# 8214           CTCF     pubmed  1214.0     28549169
# 8215         APOEε4     pubmed   440.0     29370207
# 8216          CYTH4     pubmed  1056.0     28836065
# 8217        MLN4924     pubmed   159.0     28701396
# 8218         RBP-Jκ     pubmed   886.0     28701396
# 8219          ORF50     pubmed  1185.0     28701396
# 8220         malat1     pubmed    62.0     29575609
# 8221        malat1      pubmed   305.0     29575609
# 8222         malat1     pubmed   441.0     29575609
# 8223         malat1     pubmed   597.0     29575609
# 8224         malat1     pubmed   657.0     29575609
# 8225         malat1     pubmed   864.0     29575609
# 8226         malat1     pubmed   989.0     29575609
#
#                               selection semantic_class   start  sysrev_id  \
# 0                                α-KGDH           gene   280.0    1524023
# 1                                 KAT2A           gene   386.0    1524023
# 2                                  GCN5           gene   407.0    1524023
# 3                          succinyl-CoA           gene   481.0    1524023
# 4                                 KAT2A           gene   504.0    1524023
# 5                                 KAT2A           gene   560.0    1524023
# 6                          succinyl-CoA           gene   582.0    1524023
# 7                          succinyl-CoA           gene   626.0    1524023
# 8                                 KAT2A           gene   664.0    1524023
# 9                          succinyl-CoA           gene   957.0    1524023
# 10                           acetyl-CoA           gene   975.0    1524023
# 11                                KAT2A           gene   987.0    1524023
# 12                               α-KGDH           gene  1152.0    1524023
# 13                         succinyl-CoA           gene  1420.0    1524023
# 14                              α-KGDH            gene  1449.0    1524023
# 15                                KAT2A           gene  1513.0    1524023
# 16                                 DEC2           gene   821.0    1523054
# 17                                 DEC2           gene  1159.0    1523054
# 18                                TNF-α           gene   588.0    1523665
# 19                                  TNF           gene   154.0    1523665
# 20                                  TNF           gene   783.0    1523665
# 21                               TNF-α            gene   841.0    1523665
# 22                                TNF-α           gene  1205.0    1523665
# 23                                EF-1α           gene   667.0    1524303
# 24                               EEF1A1           gene   686.0    1524303
# 25                                EF-1α           gene  1246.0    1524303
# 26                                  WT1           gene   247.0    1523292
# 27                               CTNNB1           gene   252.0    1523292
# 28                                AMER1           gene   260.0    1523292
# 29                               DROSHA           gene   267.0    1523292
# ...                                 ...            ...     ...        ...
# 8197                                JAK           gene    25.0    1523912
# 8198                              SOCS3           gene   246.0    1523912
# 8199                             p-JAK1           gene  1579.0    1523912
# 8200                             p-JAK2           gene  1587.0    1523912
# 8201                            p-STAT3           gene  1594.0    1523912
# 8202                             c-FLIP           gene    35.0    1523243
# 8203                              NF-κB           gene   134.0    1523243
# 8204                            c-FLIPL           gene   615.0    1523243
# 8205                            GADD45B           gene   776.0    1523243
# 8206                               MKK7           gene   813.0    1523243
# 8207                        phospho-JNK           gene   822.0    1523243
# 8208                                Bax           gene  1222.0    1523243
# 8209                                p53           gene   372.0    1523282
# 8210                             CDKN1a           gene   768.0    1523282
# 8211        Ets homologous factor (EHF)           gene   351.0    1524309
# 8212  Apaf-1 interacting protein (APIP)           gene   383.0    1524309
# 8213  ETS transcription factor 5 (ELF5)           gene   796.0    1524309
# 8214        CCCTC-binding factor (CTCF)           gene  1187.0    1524309
# 8215                             APOEε4           gene   434.0    1523324
# 8216                              CYTH4           gene  1051.0    1523134
# 8217                            MLN4924           gene   152.0    1523949
# 8218                             RBP-Jκ           gene   880.0    1523949
# 8219                              ORF50           gene  1180.0    1523949
# 8220                             malat1           gene    56.0    1522881
# 8221                            malat1            gene   299.0    1522881
# 8222                             malat1           gene   435.0    1522881
# 8223                             malat1           gene   591.0    1522881
# 8224                             malat1           gene   651.0    1522881
# 8225                             malat1           gene   858.0    1522881
# 8226                             malat1           gene   983.0    1522881
#
#                                                    text
# 0     Histone modifications, such as the frequently ...
# 1     Histone modifications, such as the frequently ...
# 2     Histone modifications, such as the frequently ...
# 3     Histone modifications, such as the frequently ...
# 4     Histone modifications, such as the frequently ...
# 5     Histone modifications, such as the frequently ...
# 6     Histone modifications, such as the frequently ...
# 7     Histone modifications, such as the frequently ...
# 8     Histone modifications, such as the frequently ...
# 9     Histone modifications, such as the frequently ...
# 10    Histone modifications, such as the frequently ...
# 11    Histone modifications, such as the frequently ...
# 12    Histone modifications, such as the frequently ...
# 13    Histone modifications, such as the frequently ...
# 14    Histone modifications, such as the frequently ...
# 15    Histone modifications, such as the frequently ...
# 16    Tumor hypoxia contributes to a biologically ag...
# 17    Tumor hypoxia contributes to a biologically ag...
# 18    OBJECTIVES: Several articles have provided con...
# 19    OBJECTIVES: Several articles have provided con...
# 20    OBJECTIVES: Several articles have provided con...
# 21    OBJECTIVES: Several articles have provided con...
# 22    OBJECTIVES: Several articles have provided con...
# 23    In our previous study, we demonstrated that ep...
# 24    In our previous study, we demonstrated that ep...
# 25    In our previous study, we demonstrated that ep...
# 26    We performed genome-wide sequencing and analyz...
# 27    We performed genome-wide sequencing and analyz...
# 28    We performed genome-wide sequencing and analyz...
# 29    We performed genome-wide sequencing and analyz...
# ...                                                 ...
# 8197  OBJECTIVE: Janus kinase (JAK)- signal transduc...
# 8198  OBJECTIVE: Janus kinase (JAK)- signal transduc...
# 8199  OBJECTIVE: Janus kinase (JAK)- signal transduc...
# 8200  OBJECTIVE: Janus kinase (JAK)- signal transduc...
# 8201  OBJECTIVE: Janus kinase (JAK)- signal transduc...
# 8202  Cellular FLICE inhibitory protein (c-FLIP) is ...
# 8203  Cellular FLICE inhibitory protein (c-FLIP) is ...
# 8204  Cellular FLICE inhibitory protein (c-FLIP) is ...
# 8205  Cellular FLICE inhibitory protein (c-FLIP) is ...
# 8206  Cellular FLICE inhibitory protein (c-FLIP) is ...
# 8207  Cellular FLICE inhibitory protein (c-FLIP) is ...
# 8208  Cellular FLICE inhibitory protein (c-FLIP) is ...
# 8209  Live-cell microscopy has highlighted that tran...
# 8210  Live-cell microscopy has highlighted that tran...
# 8211  Mutations in the cystic fibrosis transmembrane...
# 8212  Mutations in the cystic fibrosis transmembrane...
# 8213  Mutations in the cystic fibrosis transmembrane...
# 8214  Mutations in the cystic fibrosis transmembrane...
# 8215  Slow wave (or stage N3) sleep has been linked ...
# 8216  Uterine fibroids are benign tumors of the uter...
# 8217  The switch of Kaposi's sarcoma-associated herp...
# 8218  The switch of Kaposi's sarcoma-associated herp...
# 8219  The switch of Kaposi's sarcoma-associated herp...
# 8220  Metastasis-associated lung adenocarcinoma tran...
# 8221  Metastasis-associated lung adenocarcinoma tran...
# 8222  Metastasis-associated lung adenocarcinoma tran...
# 8223  Metastasis-associated lung adenocarcinoma tran...
# 8224  Metastasis-associated lung adenocarcinoma tran...
# 8225  Metastasis-associated lung adenocarcinoma tran...
# 8226  Metastasis-associated lung adenocarcinoma tran...
#
# [8227 rows x 9 columns]
